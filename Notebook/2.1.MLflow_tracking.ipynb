# %%
# manipulation des données
import numpy as np
import pandas as pd

# matplotlib et seaborn pour les représentations graphiques
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# sklearn preprocessing pour le traiter les variables catégorielles
from sklearn.preprocessing import LabelEncoder

# Gestion du système de fichiers
import os

# Suppression des alertes
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../Data/2.sample_dataset.csv")
df
# Out:
#      target          id                          date      flag  \
# 0         4  2057709877  Sat Jun 06 13:30:55 PDT 2009  NO_QUERY
# 1         4  1970275715  Sat May 30 03:11:00 PDT 2009  NO_QUERY
# 2         0  2000419665  Mon Jun 01 22:04:34 PDT 2009  NO_QUERY
# 3         0  1985441614  Sun May 31 17:06:32 PDT 2009  NO_QUERY
# 4         4  1977041913  Sat May 30 19:57:00 PDT 2009  NO_QUERY
# ..      ...         ...                           ...       ...
# 995       0  2058739525  Sat Jun 06 15:32:09 PDT 2009  NO_QUERY
# 996       4  2063795559  Sun Jun 07 04:06:19 PDT 2009  NO_QUERY
# 997       4  2182123994  Mon Jun 15 12:45:12 PDT 2009  NO_QUERY
# 998       4  2031935456  Thu Jun 04 10:31:53 PDT 2009  NO_QUERY
# 999       4  1694052048  Mon May 04 00:52:14 PDT 2009  NO_QUERY
#
#                user                                               text  \
# 0    tweeteradder14  get followers day using wwwtweeteraddercom onc...
# 1          ono14991               pretty good thank you imperfectangel
# 2         kennypham  plane over my house right nowand wish could be...
# 3      jleviesquire  trying out uber twitter seems better than tiny...
# 4           LSully9                 woo sounds like you had great day
# ..              ...                                                ...
# 995      rumblepurr      it really does so whats the news with you sir
# 996         karob92                          bruno asleep on the sofa
# 997         teleken   want one for the ts now still have mine in bo...
# 998    kittenfreaky  mine mine mine mine happy birthday to me happy...
# 999         franzne         touch my hand video simply amazing love it
#
#                                                  words
# 0    get follower day use wwwtweeteraddercom add ev...
# 1                     pretty good thank imperfectangel
# 2    plane house right nowand wish could wan na go ...
# 3    try uber twitter seem well tiny twitter sorry ...
# 4                             woo sound like great day
# ..                                                 ...
# 995                              really whats news sir
# 996                                  bruno asleep sofa
# 997                want one t still mine box somewhere
# 998  mine mine mine mine happy birthday happy dance...
# 999                 touch hand video simply amaze love
#
# [1000 rows x 7 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()
df = df.dropna(subset=['words'])

X_CountVecorizer = vectorizer.fit_transform(df['words'])
y_CountVecorizer = df['target']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X_TfidfVectorizer = vectorizer.fit_transform(df['words'])
y_TfidfVectorizer = df['target']

# %%
from sklearn.model_selection import train_test_split

X_train_Cv, X_test_Cv, y_train_Cv, y_test_Cv = train_test_split(X_CountVecorizer,
                                                                 y_CountVecorizer,
                                                                 test_size = 0.4,
                                                                 random_state = 42)

X_train_Tv, X_test_Tv, y_train_Tv, y_test_Tv = train_test_split(X_TfidfVectorizer,
                                                                 y_TfidfVectorizer,
                                                                 test_size = 0.4,
                                                                 random_state = 42)

# %%
from sklearn.linear_model import LogisticRegression
import mlflow

mlflow.set_experiment("Reg_Logistic_CountVectorizer")
mlflow.sklearn.autolog() 

with mlflow.start_run(run_name = 'reg_logistic_SolverLiblinear'):
  clf = LogisticRegression(solver='liblinear')
  clf.fit(X_train_Cv, y_train_Cv)
# Out:
# 2024/01/23 15:50:14 INFO mlflow.tracking.fluent: Experiment with name 'Reg_Logistic_CountVectorizer' does not exist. Creating a new experiment.
# 2024/01/23 15:50:15 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'Series' object has no attribute 'toarray'
